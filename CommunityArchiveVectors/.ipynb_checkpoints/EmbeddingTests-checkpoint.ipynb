# %%
# %pip install numpy scikit-learn matplotlib umap-learn openai google-generativeai python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy
#   Downloading numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 6.4 MB/s eta 0:00:01
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp39-cp39-macosx_12_0_arm64.whl (11.1 MB)
#      |████████████████████████████████| 11.1 MB 19.8 MB/s eta 0:00:01
# Collecting matplotlib
#   Downloading matplotlib-3.9.4-cp39-cp39-macosx_11_0_arm64.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 33.3 MB/s eta 0:00:01
# Collecting umap-learn
#   Downloading umap_learn-0.5.9.post2-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 20.1 MB/s eta 0:00:01
# Collecting openai
#   Downloading openai-2.6.1-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 23.0 MB/s eta 0:00:01
# Collecting google-generativeai
#   Downloading google_generativeai-0.8.5-py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 30.1 MB/s eta 0:00:01
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting scipy>=1.6.0
#   Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#      |████████████████████████████████| 30.3 MB 22.7 MB/s eta 0:00:01
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#      |████████████████████████████████| 308 kB 59.8 MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.60.1-cp39-cp39-macosx_10_9_universal2.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 44.6 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /Users/noasouccar/Library/Python/3.9/lib/python/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8
#   Downloading pillow-11.3.0-cp39-cp39-macosx_11_0_arm64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 90.7 MB/s eta 0:00:01
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
#      |████████████████████████████████| 113 kB 55.3 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/noasouccar/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp39-cp39-macosx_11_0_arm64.whl (64 kB)
#      |████████████████████████████████| 64 kB 19.0 MB/s eta 0:00:01
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp39-cp39-macosx_11_0_arm64.whl (249 kB)
#      |████████████████████████████████| 249 kB 53.9 MB/s eta 0:00:01
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 26.8 MB/s eta 0:00:01
# Collecting numba>=0.51.2
#   Downloading numba-0.60.0-cp39-cp39-macosx_11_0_arm64.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 100.3 MB/s eta 0:00:01
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 21.7 MB/s eta 0:00:01
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/noasouccar/Library/Python/3.9/lib/python/site-packages (from openai) (4.15.0)
# Collecting jiter<1,>=0.10.0
#   Downloading jiter-0.11.1-cp39-cp39-macosx_11_0_arm64.whl (305 kB)
#      |████████████████████████████████| 305 kB 40.5 MB/s eta 0:00:01
# Collecting pydantic<3,>=1.9.0
#   Downloading pydantic-2.12.3-py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 35.4 MB/s eta 0:00:01
# Requirement already satisfied: sniffio in /Users/noasouccar/Library/Python/3.9/lib/python/site-packages (from openai) (1.3.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/noasouccar/Library/Python/3.9/lib/python/site-packages (from openai) (4.11.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/noasouccar/Library/Python/3.9/lib/python/site-packages (from openai) (0.28.1)
# Collecting google-ai-generativelanguage==0.6.15
#   Downloading google_ai_generativelanguage-0.6.15-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 59.2 MB/s eta 0:00:01
# Collecting protobuf
#   Downloading protobuf-6.33.0-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
#      |████████████████████████████████| 427 kB 85.1 MB/s eta 0:00:01
# Collecting google-auth>=2.15.0
#   Downloading google_auth-2.42.0-py2.py3-none-any.whl (222 kB)
#      |████████████████████████████████| 222 kB 89.5 MB/s eta 0:00:01
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.185.0-py3-none-any.whl (14.5 MB)
#      |████████████████████████████████| 14.5 MB 60.4 MB/s eta 0:00:01
# Collecting google-api-core
#   Downloading google_api_core-2.28.1-py3-none-any.whl (173 kB)
#      |████████████████████████████████| 173 kB 78.5 MB/s eta 0:00:01
# Collecting protobuf
#   Downloading protobuf-5.29.5-cp38-abi3-macosx_10_9_universal2.whl (418 kB)
#      |████████████████████████████████| 418 kB 13.6 MB/s eta 0:00:01
# Collecting proto-plus<2.0.0dev,>=1.22.3
#   Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 22.9 MB/s eta 0:00:01
# Requirement already satisfied: idna>=2.8 in /Users/noasouccar/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/noasouccar/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->openai) (1.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /Users/noasouccar/Library/Python/3.9/lib/python/site-packages (from google-api-core->google-generativeai) (2.32.5)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2
#   Downloading googleapis_common_protos-1.71.0-py3-none-any.whl (294 kB)
#      |████████████████████████████████| 294 kB 32.6 MB/s eta 0:00:01
# Collecting grpcio-status<2.0.0,>=1.33.2
#   Downloading grpcio_status-1.76.0-py3-none-any.whl (14 kB)
# Collecting grpcio<2.0.0,>=1.33.2
#   Downloading grpcio-1.76.0-cp39-cp39-macosx_11_0_universal2.whl (11.8 MB)
#      |████████████████████████████████| 11.8 MB 105.3 MB/s eta 0:00:01
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Collecting cachetools<7.0,>=2.0.0
#   Downloading cachetools-6.2.1-py3-none-any.whl (11 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 30.9 MB/s eta 0:00:01
# Collecting grpcio-status<2.0.0,>=1.33.2
#   Downloading grpcio_status-1.75.1-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.75.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.74.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.73.1-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.73.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.72.2-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.72.1-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.71.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: httpcore==1.* in /Users/noasouccar/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: certifi in /Users/noasouccar/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: h11>=0.16 in /Users/noasouccar/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/noasouccar/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Collecting llvmlite<0.44,>=0.43.0dev0
#   Downloading llvmlite-0.43.0-cp39-cp39-macosx_11_0_arm64.whl (28.8 MB)
#      |████████████████████████████████| 28.8 MB 16.9 MB/s eta 0:00:01
# Collecting pyasn1<0.7.0,>=0.6.1
#   Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 8.6 MB/s  eta 0:00:01
# Collecting pydantic-core==2.41.4
#   Downloading pydantic_core-2.41.4-cp39-cp39-macosx_11_0_arm64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 101.1 MB/s eta 0:00:01
# Collecting typing-inspection>=0.4.2
#   Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/noasouccar/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/noasouccar/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.5.0)
# Collecting httplib2<1.0.0,>=0.19.0
#   Downloading httplib2-0.31.0-py3-none-any.whl (91 kB)
#      |████████████████████████████████| 91 kB 37.4 MB/s eta 0:00:01
# Collecting uritemplate<5,>=3.0.1
#   Downloading uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Installing collected packages: pyasn1, rsa, pyasn1-modules, protobuf, cachetools, pyparsing, proto-plus, numpy, grpcio, googleapis-common-protos, google-auth, threadpoolctl, scipy, llvmlite, joblib, httplib2, grpcio-status, google-api-core, uritemplate, typing-inspection, scikit-learn, pydantic-core, numba, google-auth-httplib2, annotated-types, tqdm, pynndescent, pydantic, pillow, kiwisolver, jiter, importlib-resources, google-api-python-client, google-ai-generativelanguage, fonttools, distro, cycler, contourpy, umap-learn, python-dotenv, openai, matplotlib, google-generativeai
#   WARNING: The scripts pyrsa-decrypt, pyrsa-encrypt, pyrsa-keygen, pyrsa-priv2pub, pyrsa-sign and pyrsa-verify are installed in '/Users/noasouccar/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts f2py and numpy-config are installed in '/Users/noasouccar/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tqdm is installed in '/Users/noasouccar/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/Users/noasouccar/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script distro is installed in '/Users/noasouccar/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script dotenv is installed in '/Users/noasouccar/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script openai is installed in '/Users/noasouccar/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed annotated-types-0.7.0 cachetools-6.2.1 contourpy-1.3.0 cycler-0.12.1 distro-1.9.0 fonttools-4.60.1 google-ai-generativelanguage-0.6.15 google-api-core-2.28.1 google-api-python-client-2.185.0 google-auth-2.42.0 google-auth-httplib2-0.2.0 google-generativeai-0.8.5 googleapis-common-protos-1.71.0 grpcio-1.76.0 grpcio-status-1.71.2 httplib2-0.31.0 importlib-resources-6.5.2 jiter-0.11.1 joblib-1.5.2 kiwisolver-1.4.7 llvmlite-0.43.0 matplotlib-3.9.4 numba-0.60.0 numpy-2.0.2 openai-2.6.1 pillow-11.3.0 proto-plus-1.26.1 protobuf-5.29.5 pyasn1-0.6.1 pyasn1-modules-0.4.2 pydantic-2.12.3 pydantic-core-2.41.4 pynndescent-0.5.13 pyparsing-3.2.5 python-dotenv-1.2.1 rsa-4.9.1 scikit-learn-1.6.1 scipy-1.13.1 threadpoolctl-3.6.0 tqdm-4.67.1 typing-inspection-0.4.2 umap-learn-0.5.9.post2 uritemplate-4.2.0
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from umap import UMAP
from sklearn.metrics.pairwise import cosine_similarity
import openai
import google.generativeai as genai
import os

# %%
# Load OpenAI embeddings
with open('embeddings_output.json', 'r') as f:
    openai_data = json.load(f)

# Load Gemini embeddings
with open('embeddings_output_gemini.json', 'r') as f:
    gemini_data = json.load(f)

print(f" Loaded {len(openai_data)} OpenAI embeddings")
print(f" Loaded {len(gemini_data)} Gemini embeddings")
print(f"OpenAI dimensions: {len(openai_data[0]['embedding'])}")
print(f"Gemini dimensions: {len(gemini_data[0]['embedding'])}")
# Out:
#  Loaded 1000 OpenAI embeddings
#  Loaded 1000 Gemini embeddings
# OpenAI dimensions: 1536
# Gemini dimensions: 768

# %%
penai_embeddings = np.array([item['embedding'] for item in openai_data])
openai_depths = [item['depth'] for item in openai_data]
openai_is_root = [item['is_root'] for item in openai_data]

# Apply t-SNE (this may take a minute)
print("Running t-SNE on OpenAI embeddings...")
tsne = TSNE(n_components=2, random_state=42, perplexity=30, max_iter=1000)
openai_2d = tsne.fit_transform(openai_embeddings)

# Plot colored by thread depth
plt.figure(figsize=(14, 10))
scatter = plt.scatter(openai_2d[:, 0], openai_2d[:, 1], 
                     c=openai_depths, cmap='viridis', 
                     alpha=0.6, s=30)
plt.colorbar(scatter, label='Thread Depth')
plt.title('OpenAI Embeddings (text-embedding-3-small)\nt-SNE Visualization - Colored by Thread Depth', 
          fontsize=14, fontweight='bold')
plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Running t-SNE on OpenAI embeddings...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       5 # Apply t-SNE (this may take a minute)
#       6 print("Running t-SNE on OpenAI embeddings...")
# ----> 7 tsne = TSNE(n_components=2, random_state=42, perplexity=30, n_iter=1000)
#       8 openai_2d = tsne.fit_transform(openai_embeddings)
#      10 # Plot colored by thread depth
#
# TypeError: TSNE.__init__() got an unexpected keyword argument 'n_iter'
